# %%
from model.dcgan import Generator, Discriminator, initialize_weights
from utils.dataset import ImageFolder
from utils.gan_process import training_loops
from utils.transforms import _get_test_transforms
from torch.utils.data import DataLoader
import torch.optim as optim
import torch
import torch.nn as nn

# %% [markdown]
# ## Define hyperparameter

# %%
LEARNING_RATE = 2e-4  # could also use two lrs, one for gen and one for disc
BATCH_SIZE = 64
IMAGE_SIZE = 300
CHANNELS_IMG = 3
Z_DIM = 200
NUM_EPOCHS = 100
FEATURES_DISC = 128
FEATURES_GEN = 128

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %% [markdown]
# ## Init model

# %%
gen_model = Generator(1, Z_DIM, FEATURES_GEN, CHANNELS_IMG).to(device)

disc_model = Discriminator(CHANNELS_IMG, FEATURES_DISC).to(device)

initialize_weights(gen_model)
initialize_weights(disc_model)

# %% [markdown]
# ## Init data

# %%
dataset = ImageFolder(
    root_dir=r"",
    transform=_get_test_transforms(IMAGE_SIZE),
)
data_loader = DataLoader(
    dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 dataset = ImageFolder(
#       2     root_dir="data/thyroid_gan",
#       3     transform=_get_test_transforms(IMAGE_SIZE),
#       4 )
#       5 train_loader = DataLoader(
#       6     dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0
#       7 )
#
# File d:\workspace\wyshieh_workspace\side-project\thyroid-ai\utils\dataset.py:17, in ImageFolder.__init__(self, root_dir, transform)
#      11 self.transform = transform
#      12 self.image_paths = sorted(glob(os.path.join(root_dir, "*", "*.*")))
#      14 self.class_names = sorted(
#      15     [
#      16         d
# ---> 17         for d in os.listdir(root_dir)
#      18         if os.path.isdir(os.path.join(root_dir, d))
#      19     ]
#      20 )
#      21 self.class_to_idx = {cls_name: i for i, cls_name in enumerate(self.class_names)}
#      23 self.labels = [
#      24     self.class_to_idx[os.path.basename(os.path.dirname(p))]
#      25     for p in self.image_paths
#      26 ]
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'data/thyroid_gan'

# %% [markdown]
# ## Define optimizer

# %%
gen_opt = optim.Adam(gen_model.parameters(), lr=LEARNING_RATE, betas=(0.5, 0.999))
disc_opt = optim.Adam(disc_model.parameters(), lr=LEARNING_RATE, betas=(0.5, 0.999))

# %% [markdown]
# ## Define loss

# %%
criterion = nn.BCELoss()

# %% [markdown]
# ## Training processs

# %%
training_loops(
    gen_model=gen_model,
    disc_model=disc_model,
    noise_dim=Z_DIM,
    data_loader=data_loader,
    criterion=criterion,
    gen_optimizer=gen_opt,
    disc_optimizer=disc_opt,
    device=device,
    num_epochs=NUM_EPOCHS,
    save_path=r"gan_checkpoints",
)
